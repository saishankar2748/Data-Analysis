# %% [markdown]
# ## Data Visualisation - Graded Questions

# %% [markdown]
# `Note` - *This stub file doesn't contain the conceptual questions asked on the platform*

# %% [markdown]
# ### I) Marks Analysis
#
# In the **'Marks.csv'** file, you can find the scores obtained by 200 students in 4 subjects of a standardised test. The different columns - `Score A`, `Score B`, `Score C` and `Score D` indicate the score obtained by a particular student in the respective subjects A, B, C and D.
#
#
#
# Load the dataset to your notebook and answer the following questions

# %%
#Load the necessary Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset
df1 = pd.read_csv('Marks.csv')
df1
# Out:
#      Score A  Score B  Score C  Score D
# 0      230.1     37.8     69.2     22.1
# 1       44.5     39.3     45.1     10.4
# 2       17.2     45.9     69.3     12.0
# 3      151.5     41.3     58.5     16.5
# 4      180.8     10.8     58.4     17.9
# ..       ...      ...      ...      ...
# 195     38.2      3.7     13.8      7.6
# 196     94.2      4.9      8.1     14.0
# 197    177.0      9.3      6.4     14.8
# 198    283.6     42.0     66.2     25.5
# 199    232.1      8.6      8.7     18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# **Q1)** Load the dataset and plot a histogram for the `Score A` column by keeping the `number of bins to 6`. Which bin range among the following has the highest frequency?
#
# (`Note` - *The bin ranges mentioned in the options are approximate values for the bin ranges that you'll actually get when you plot the histogram*)
#
#     a)0-50
#     b)50-100
#     c)150-200
#     d)200-250

# %%
#Your code here
plt.hist(df1['Score A'],bins=6,edgecolor='white')
plt.show()

# %% [markdown]
# **Q2)** Plot a box plot for the column `Score C` and choose the correct option.
#
#     A - The 25th percentile lies between 20 and 40
#     B - The 75th percentile lies between 40 and 60
#     C - The 25th percentile lies between 0 and 20
#     D - Both B and C

# %%
#Your code here
sns.boxplot(df1['Score C'])
plt.show()
# Out:
# C:\Users\saish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(df1)

# %% [markdown]
# ### II) Superstore Data
#
# In the `superstore.csv` file, you have the details of orders purchased in an American online retail store. Load the dataset, observe and analyse the different columns and answer the following questions.

# %%
#Load the dataset
df2 = pd.read_csv('superstore.csv')
df2
# Out:
#             Order ID       Ship Mode    Segment Region       Product ID  \
# 0     CA-2016-152156    Second Class   Consumer  South  FUR-BO-10001798
# 1     CA-2016-152156    Second Class   Consumer  South  FUR-CH-10000454
# 2     CA-2016-138688    Second Class  Corporate   West  OFF-LA-10000240
# 3     US-2015-108966  Standard Class   Consumer  South  FUR-TA-10000577
# 4     US-2015-108966  Standard Class   Consumer  South  OFF-ST-10000760
# ...              ...             ...        ...    ...              ...
# 9989  CA-2014-110422    Second Class   Consumer  South  FUR-FU-10001889
# 9990  CA-2017-121258  Standard Class   Consumer   West  FUR-FU-10000747
# 9991  CA-2017-121258  Standard Class   Consumer   West  TEC-PH-10003645
# 9992  CA-2017-121258  Standard Class   Consumer   West  OFF-PA-10004041
# 9993  CA-2017-119914    Second Class   Consumer   West  OFF-AP-10002684
#
#          Sales  Quantity Discount    Profit
# 0     261.9600         2       0%   41.9136
# ...

# %%
df2[df2['Profit']==df2['Profit'].max()]
# Out:
#             Order ID       Ship Mode    Segment   Region       Product ID  \
# 6826  CA-2016-118689  Standard Class  Corporate  Central  TEC-CO-10004722
#
#          Sales  Quantity Discount    Profit
# 6826  17499.95         5       0%  8399.976

# %%
df2.groupby('Product ID')['Profit'].max().sort_values()
# Out:
# Product ID
# TEC-MA-10004125   -3839.9904
# TEC-MA-10002412   -1811.0784
# TEC-MA-10001695    -938.2800
# TEC-PH-10002645    -374.9925
# TEC-MA-10000904    -319.1916
#                      ...
# TEC-MA-10001127    2799.9840
# OFF-BI-10003527    3177.4750
# OFF-BI-10001120    4630.4755
# OFF-BI-10000545    4946.3700
# TEC-CO-10004722    8399.9760
# Name: Profit, Length: 1862, dtype: float64

# %%
df2[df2['Product ID']=='TEC-CO-10004722']
# Out:
#             Order ID       Ship Mode      Segment   Region       Product ID  \
# 2623  CA-2017-127180     First Class  Home Office     East  TEC-CO-10004722
# 4190  CA-2017-166709  Standard Class     Consumer     East  TEC-CO-10004722
# 6425  CA-2016-143714  Standard Class     Consumer     East  TEC-CO-10004722
# 6826  CA-2016-118689  Standard Class    Corporate  Central  TEC-CO-10004722
# 8153  CA-2017-140151     First Class     Consumer     West  TEC-CO-10004722
#
#           Sales  Quantity Discount     Profit
# 2623  11199.968         4    0.20%  3919.9888
# 4190  10499.970         3       0%  5039.9856
# 6425   8399.976         4    0.40%  1119.9968
# 6826  17499.950         5       0%  8399.9760
# 8153  13999.960         4       0%  6719.9808

# %%
sns.jointplot(df2['Sales'],df2['Profit'],kind='reg')
# Out:
# C:\Users\saish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2[(df2['Sales']<15000) & (df2.Profit<0)].plot(kind='scatter',x='Sales',y='Profit')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %%
df3 = df2[(df2.Profit < 0) & (df2.Sales < 15000)]
sns.jointplot('Sales', 'Profit', df3)
plt.show()
# Out:
# C:\Users\saish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2.groupby(['Segment','Ship Mode'])[['Profit']].mean()
# Out:
#                                Profit
# Segment     Ship Mode
# Consumer    First Class     27.794595
#             Same Day        31.148913
#             Second Class    24.457756
#             Standard Class  25.259011
# Corporate   First Class     29.823654
#             Same Day        15.948612
#             Second Class    29.927279
#             Standard Class  31.716781
# Home Office First Class     46.237056
#             Same Day        37.494747
#             Second Class    45.170921
#             Standard Class  26.791720

# %%
res = pd.pivot_table(data=df2,index='Segment',columns='Ship Mode',values='Profit')
res
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer       27.794595  31.148913     24.457756       25.259011
# Corporate      29.823654  15.948612     29.927279       31.716781
# Home Office    46.237056  37.494747     45.170921       26.791720

# %%
res = pd.pivot_table(data=df2,index='Segment',columns='Ship Mode',values='Profit')
sns.heatmap(res,annot=True)
# Out:
# <AxesSubplot:xlabel='Ship Mode', ylabel='Segment'>

# %%
sns.barplot(data=df2,x='Segment',y='Sales')
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Sales'>

# %% [markdown]
# **Q4)** Plot a pie-chart to find the Ship Mode through which most of the orders are being delivered.
#
#      a)Standard Class
#      b)First Class
#      c)Second Class
#      d)Same Day

# %%
df2['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
#Your code here
df2['Ship Mode'].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='Ship Mode'>

# %% [markdown]
# **Q5)** Plot a bar chart comparing the average `Discount` across all the `Regions` and report back the `Region` getting the highest average discount
#
# **Note** - You need to clean the `Discount` column first
#
#     a)Central
#     b)South
#     c)West
#     d)East

# %%
#Your code here
df2.Region.value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df2.Discount.value_counts()
# Out:
# 0%       4798
# 0.20%    3657
# 0.70%     418
# 0.80%     300
# 0.30%     227
# 0.40%     206
# 0.60%     138
# 0.10%      94
# 0.50%      66
# 0.15%      52
# 0.32%      27
# 0.45%      11
# Name: Discount, dtype: int64

# %%
df2['Discount'].replace(r'%','',regex=True,inplace=True)
df2['Discount'] = df2['Discount'].astype(float)

# %%
df2.groupby('Region')['Discount'].mean()
# Out:
# Region
# Central    0.240353
# East       0.145365
# South      0.147253
# West       0.109335
# Name: Discount, dtype: float64

# %%
sns.barplot(df2.Region,df2.Discount)
# Out:
# C:\Users\saish\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='Discount'>
